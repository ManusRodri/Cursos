# %% [markdown]
# # Que es un mercado financiero?
# + Un mercado financiero es un espacio ya sea fisico o virtual, en este espacio compradores y vendedores intercambian activos, con agentes economicos de por medio.
#
# + Este sistema facilita la interaccion entre aquellas personas o entidades que cuentan con el capital para invertir y las que nesecitan capital.
#
# + Caracteristicas de un mercado financiero
#
#   1. Amplitud: cuenta con un volumen significativo de activos y liquidez
#
#   2. Transparencia: la informacion monetaria de los activos debe ser publico para todas las personas. Puede verse desde graficos y estadisticas
#
#   3. Libertad: puedes comprar y vender en cualquier momento
#
#   4. Profundidad: cuantas mayores operaciones de compra / venta que hayan en el mercado, mas profundo es
#
#   5. Flexibilidad: liquidez y facilidad de compra / venta
#
# + Tipos de mercados financieros:
#
#   1. Mercados monetarios: Donde se ejecutan transacciones interbancarias, deuda publica y se maneja nuestra moneda.
#
#   2. Mercados de capitales: Se refiere a los mercados de renta fija o renta variable o los derivados financieros
#
#   3. Mercado de acciones: En este mercado se realiza la compra/venta de titulos de propiedad de compañias publicas, por ejemplo: Apple, Tesla, Google, Meta, etc.
#
#   4. Mercado de futuros: Es un acuerdo entre dos inversionistas en el que se comprometen a comprar y vender un activo, acordando en el momento en que se realice el intercambio las condiciones de dicha compraventa en el futuro.
#
#   5. Mercados de materias primas: oro, plata, petroleo, etc
#
#   6. Mercado de divisas (Forex):  Mercados de intercambio de divisas, por ejemplo: dolar-euro, euro-libra esterlina, etc.
#
#   7. Mercado de criptodivisas: En este mercado se realiza la compra y venta de criptoactivos, el mas conocido es Bitcoin; sin embargo, existen miles de proyectos con Ether, BNB, Solana, USD Coin, etc.
#
# # Que es un activo financiero?
#
# + es un instrumento que tiene valor o puede generar ingresos. Es un documento o titulo emitido por una empresa, banco, institucion privada o publica, cuyo comprador o propietario espera que le produzca rendimientos.
#
# # Que es un CDF?
# + De sus siglas en ingles, un Contract For Difference es un contrato que se basa en el cambio del valor de los activos financieros mediante el cual el comprador paga al vendedor para adquirir un activo adyacente que cambiara de valor en el tiempo.
#
#   * Si la diferencia es positiva, el vendedor paga la diferencia al comprador.
#
#   * Si la diferencia es negativa, el comprador es quien debe pagar la diferencia al vendedor.

# %% [markdown]
# # Tipos de analisis de mercado
#
# + Analisis Técnico
# + Analisis Fundamental
# + Analisis Macroeconómico
# + Analisis Cuantitativo
#
#
# ## Analisis tecnico:
#
# + El analisis tecnico estudia los movimientos del mercado a traves de los graficos e indicadores basados en calculos estadisticos.
#
# + ![image.png](attachment:d4f2d56f-ca0c-47c3-845c-da0341dfd2bc.png)
# + ![image.png](attachment:300b1afe-5bad-4f80-8793-8538885e83c2.png)
#
# ## Analisis fundamental:
#
# + El analisis fundamental nos ayuda a conocer el valor intrinseco de un activo, es decir, el valor al que deberia cotizar, de este modo podemos conocer si este activo, esta sub valuado o sobre valuado y asi tomar decisiones de inversion acertadas.
#
# + ![image.png](attachment:f1b06664-77a3-40ea-859f-839b2dd70dbb.png)
#
# ## Analisis macroeconomico:
#
# + Estudia el comportamiento y el desarrollo global de la economia de un pais.
#
# ## Analisis cuantitativo:
#
# + Utiliza tecnicas matematicas y estadisticas para explicar, o pronosticar, distintas variables economicas.
#
# # Que es el trading?
#
# + Arte de especular en los mercados financieros con el objetivo de generar resultados positivos en un tiempo determinado.
#
# ## Tipo de trading:
#
# + Trading Discrecional: decisiones tomadas por nosotros mismos basado en proyecciones que hemos realizado.
#
# + Trading Algoritmico: decisiones tomadas por algoritmos.

# %% [markdown]
# # Analisis tecnico
#
# + El analisis tecnico es el estudio de los movimientos de precio de un activo financiero, con el objetivo de hacer proyecciones a partir de graficos y de esa forma poder tomar mejores decisiones de inversion.
#
# + El analisis tecnico tiene un cierto margen de error, pero el conjunto de herramientas y estrategias nos pueden ayudar a tomar mejores decisiones y disminuir los riesgos. Tambien es importante tener en cuenta el gestionar y cuidar nuestro capital, manejar y gestionar de manera correcta nuestras emociones y estudiar y analizar los diferentes indicadores.
#
# + Filosofia del analisis tecnico:
#
#   * Los movimientos del precio lo cuentan todo.
#
#   * Los precios se mueven por tendencias.
#
#   * La historia se repite.

# %% [markdown]
# # Analista tecnico
#
# + Especula a partir de la fluctuacion de los precios de un activo financiero de forma profesional.
#
# ## Tipos (Estos son los mas principales):
#
# - **Scalper**
#   - **Temporalidad:** Segundos a minutos
#   - **Tiempo de operaciones:** Muy corto plazo
#   - **Explicacion:** Realiza muchas operaciones en el mismo dia buscando pequenas ganancias acumuladas
#
# - **Day trader (Intradia)**
#   - **Temporalidad:** Minutos a horas
#   - **Tiempo de operaciones:** Dentro del mismo dia
#   - **Explicacion:** Aprovecha la volatilidad diaria y nunca deja posiciones abiertas de un dia a otro
#
# - **Swing trader**
#   - **Temporalidad:** Dias a semanas
#   - **Tiempo de operaciones:** Mediano plazo
#   - **Explicacion:** Mantiene posiciones varios dias para aprovechar oscilaciones del mercado
#
# - **Position trader**
#   - **Temporalidad:** Semanas a meses o años
#   - **Tiempo de operaciones:** Largo plazo
#   - **Explicacion:** Se basa en analisis fundamental y macroeconomico para seguir grandes tendencias
#
# ### Ventajas y desventajas:
#
# #### **Scalper**
#
# * **Ventajas**
#
#   * Muchas oportunidades de entrada y salida
#   * Acumula pequenas ganancias que se vuelven significativas
#   * Baja exposicion a grandes movimientos en contra
#
# * **Desventajas**
#
#   * Alta presion y estres por la velocidad
#   * Requiere atencion constante
#   * Comisiones y spreads reducen rentabilidad
#
# ---
#
# #### **Day trader (Intradia)**
#
# * **Ventajas**
#
#   * Se aprovecha de la volatilidad diaria
#   * Resultados rapidos al final del dia
#   * Mayor flexibilidad en gestion de capital
#
# * **Desventajas**
#
#   * Requiere muchas horas frente a la pantalla
#   * Necesita reaccion rapida y control emocional
#   * Alta exposicion a noticias intradia
#
# ---
#
# #### **Swing trader**
#
# * **Ventajas**
#
#   * Menor demanda de tiempo
#   * Aprovecha movimientos amplios
#   * Menores comisiones que scalping
#
# * **Desventajas**
#
#   * Riesgo de mantener posiciones abiertas de noche o fin de semana
#   * Requiere paciencia y disciplina
#   * Noticias inesperadas pueden cambiar la tendencia
#
# ---
#
# #### **Position trader**
#
# * **Ventajas**
#
#   * Menos operaciones, menos estres
#   * Puede obtener grandes ganancias en tendencias
#   * Requiere poco monitoreo constante
#
# * **Desventajas**
#
#   * Alta exposicion a riesgos macro o politicos
#   * Capital inmovilizado por largo tiempo
#   * Dificil mantener confianza en retrocesos prolongados
#
# ---
#
# # Que necesita un analista?
#
# + Conocimientos sobre finanzas y economia.
#
# + Grandes nociones de informatica.
#
# + Ingles.
#
# + Controlar las emociones.

# %% [markdown]
# ## Nota:
#
# + Antes de empezar a tomar decisiones de inversion, deberas conocer una estadistica muy importante para tener en cuenta dentro del ecosistema de trading llamada la regla del 90,90,90. Esta tendencia nos ayuda a antcipar cambios y comprender como funciona el camino de un trader.
#
# # Regla 90,90,90
#
# + El 90% de los inversionistas principiantes pierden el 90% de su dinero los primeros 90 días de aprendizaje. De ese 10% restante, solo la mitad logra ser rentable y la otra mitad consigue no perder su dinero.
#
# + La clave de la rentabilidad es la consistencia y junto a otros factores se encontrara el camino correcto.
#
# `Consistencia + Practica + Concimiento`
#
# ## Como alcanzar la consistencia?
#
# + Alcanzar la consistencia significa centrarte en el proceso, por que no podras ganar todas las veces, pero puedes acercarte cada vez mas para alcanzar un resultado gratificante.
#
# ### Piensa en el aprendizaje y luego en las ganancias
#
# + Primero piensa en aprender y luegon generar una gran recompensa.
#
# + El mundo de trading tiene existen muchas herramientas para armar tu estrategia y aumnetar tus ingresos, para eso debes seguir 5 simples fundamentos:
#
#   * Instruyete
#   * Aprende
#   * Busca libros/cursos
#   * Practica
#   * Gana
#
# ### Invierte tiempo y se paciente para formarte
#
# + Estudiar todos los conceptos tecnicos de trading es mucha informacion o estudiar cualquier otro tema, por eso se requiere tiempo y paciencia, lo que significa que el trading y el analisis de mercado no es un hobby, si no una profesion.
#
# ### Construye un sistema que se adapte a ti
#
# + El trading o cualquier otra labor se debe consttruir un sistema que este de acuerdo al perfil de uno:
#
#   * Tus objetivos
#   * Tu tiempo libre
#   * Tu capital de inversion
#   * Tu mercado de interes
#
# ### Centrate en aplicar el sistema y mejorarlo constantemente
#
# + Siempre existe la probabilidad de falla, por eso mejorar el sistema constantemente es crucial, tambien es importante el manejo de las emociones, esto debidom a que al inicio puedes tener grandes resultados, pero esa suerte puede cambiar, debido a que la suerte es la combinacion entre `Preparacion + Actitud + Oportunidad + Accion`.
#
# ### Espera los beneficios despues de hacer bien tu tarea y ser consistente
#
# + Los beneficios van a lllegar despues de entender como tomar una buena decision. Siempre enfocate en hacer bien las cosas y desarrollar tu sistema, valida y acepta todos los errores y tomalos como una enseñanza.
#
# ### Manten beneficios estables y gestiona el riesgo
#
# + Lo unico que uno puede controlar en el mundo del trading es cuanto puedes llegar a perder, por lo cual es importante tener y mantener beneficios estables en el tiempo.
#
# + A veces cuando las personas se apasionan en este campo de las finanzas, la avaricia y el ego llegan y puede significar decisiones mas riesgosas lo que conlleve a obstaculos al momento de avanzar y no lograr alcanzar ese punto de consistencia y de exito.
#
# + `Nota: La consistencia no es ganar un monton de dinero en un solo dia. Es generar resultados positivos y negativos con nuestras decisiones, para al final encontrar un resultado positivo.`
#
# ### Domina tus emociones, trabaja en ti y construye habitos
#
# + Trabaja en tus emociones para que no afecten tu toma de decisiones y construye nuevos y buenos habitos porque esta profesion no solo te permite avanzar de forma profesional, sino que te hara crecer como persona. Siempre es importante tener en cuenta lo siguiente, `Vas a ganar y a perder, pero el camino es lo que vale, es mejor tomar los triunfos y perdidas como una enseñanza que tomarlos como una derrota.`
#
# ### Nota:
#
# + `Uno no le enseñanza al mercado, el mercado es el maestro de uno.`

# %% [markdown]
# # Plataformas de inversion
#
# + Un Broker, plataforma de intercambio o inversion, es un programa informatico que te permite realizar operaciones con instrumentos financieros en tiempo real. Estas entidades funcionan como intermediarios, ejecutando las ordenes del mercado bursatil, y el trader es quien opera la plataforma.
#
# ## Que es un broker financiero
#
# - **Broker**
#   - Es una entidad o empresa financiera que:
#     - Ejecuta ordenes de compra y venta de activos en los mercados bursatiles
#     - Cobra comisiones por este servicio
#     - Cuenta con licencia para la compra y venta de acciones
#     - Es necesario para que los traders puedan operar en dichos mercados
#
# - **Diferencia entre broker y trader**
#   - Los brokers proveen la plataforma y los medios para realizar operaciones en el mercado
#   - Los traders utilizan esa plataforma para efectuar compras y ventas
#   - Los traders no pueden operar directamente en el mercado sin un broker
#
# ## Como elegir un broker?
#
# + Para elegir tu broker de preferencia es importante tener en cuenta los siguientes factores:
#
# + ![image.png](attachment:dca986e3-d273-484d-a639-b42c1e1ed291.png)
# + ![image.png](attachment:61e06b11-050a-42bc-8637-09288cb9c889.png)
#
# ## Tipos de cuentas broker
# + Los brokers nos permiten tener diferentes tipos de cuentas:
#
#   * Paper trading o cuentas demo: son las cuentas que manejan dinero ficticio y sirven para practicar y poner a prueba nuestra estrategia.
#   * Cuentas reales: son las cuentas en la que ya se hacen los movimientos reales con dinero real, usando nuestras estrategias.
#
# # Nota:
# + `Pon aprueba tu sistema en cuentas de prueba primero (cuentas demo), luego de un tiempo, inicia tu proceso en una cuenta real con poco capital, esto te permitira probar tu destresa y manejo de emociones y que ese dinero sea uno al que puedas renunciar`

# %% [markdown]
# # Conceptos importantes
# ## Accion de precio
# + ![image.png](attachment:179ff016-7936-4cd5-940e-57ec846a2c1d.png)
#
# + Oferta = Bear
# + Demanda = Bull
#
# ## Temporalidades
#
# + Es el tiempo que representa cada vela
#
# ## `Mas informacion en los apuntes de Fundamentos del trading`

# %% [markdown]
# + Los activos financieros se representan a partir de graficos, estos sirven para poderlos analizarlos mas facilmente. En estos graficos usualmente vas a encontrar 2 ejes:
#
# + ![image.png](attachment:d1d9502b-593f-468c-8ed2-aeff3b518eaa.png)
#
# + El eje (x) representa el tiempo y el eje (y) representa el precio, es decir, oferta y demanda.
#
# + Cada activo tiene su acronimo, por ejemplo:
#   * Bitcoin - BTC
#   * Dolar Estadounidense - USD
#
# + Los activos se encuentran nombrados junto a un equivalente (otra moneda) para comparar:
#   * 1 BTC → X USD
#
# ## Tipos de graficos
#
# + Los graficos muestran el como un activo financiero se ha movido por el paso del tiempo, existen varios tipos, algunos de los mas importantes son:
#
# 1. Grafico de lineas
#    + ![image.png](attachment:66fffe0b-fced-433a-a974-93dc516355bc.png)
#
#    + Este tipo de grafico solo tiene en cuenta el precio de cierre de un activo, es decir, el percio final en el que termino al finalizar la temporalidad
#
#    + Es una granm herramienta para nuevos analisis
#
#    + Nos ayuda a encontrar niveles muy importantes en el precio
#
#    + No toma en cuenta los precios de apertura u otros espacios
#
# 2. Grafico de barras
#    + ![image.png](attachment:6d6f2452-6b29-4483-8aa2-ced05a3ed121.png)
#
#    + Los graficos de barras tienen en cuenta el precio de cierre y el precio de apertura, el precio maximo y el precio minimo de la temporalidad elegida
#
# 3. Grafico de velas japonesas
#    + ![image.png](attachment:a7146428-1d3b-4292-ba61-18ff53d932a0.png)
#    + ![image.png](attachment:97c044d7-3f6d-4393-9d4b-947b1fd2b17a.png)
#
#    + En los graficos de velas japonesas tenemos un cuerpo con diferentes partes y colores.
#
#      * El color verde representa la intencion de demanda (compra)
#      * EL color rojo representa la intencion de oferta (venta)
#
#    + Aca es donde aparece los bulls, qeu son la representacion grafica de los compradores, y los bears, que son la representacion grafica de los vendedores.
#
#    + Funcion de los graficos de velas japonesas:
#
#      * Evaluar el interes del precio de un activo en el mercado
#      * Obtener informacion del precio y patrones que nos ayuden a intentar predecir el mercado y nos ayuden a tyomar decisiones mas efectivas
#      * Generar una lectura facil por el uso de colores
#
# # Que buscamos al evaluar el precio de un activo
#
# + Existen 3 variables las cuales son muy importantes en esta profesion:
#
#   * Oferta
#   * Demanda
#   * Interes

# %% [markdown]
# # Tendencias de mercado
#
# + El precio de un activo financiero se mueve por medio de tendencias, las cuales estan formadas por una sucesion de maximos y minimos
#
# + Son la direccion que siguen los precios del mercado, es decir, hacia donde se estan dirigiendo los precios
#
# ## Que buscamos
#
# + Tendencias sostenidas en el tiempo con una pendiente entorno a los 45 grados
#
# + Tendencias fuertes con una pendiente casi vertical y que normalmente muestran una menor duracion en el tiempo
#
# + Se utilizan las lineas de tendencia para medir la fortaleza de el movimiento de la accion
#
# ## Tipos de tendencias
#
# + Alcistas
# + Bjistas
# + Lterales
#
#   * ![image.png](attachment:26113d1f-145c-40eb-918e-92efa4419b8e.png)
#
#
# ## Nomenclatura
#
# - **H (High)**
#   - Precio alto o maximo alcanzado en una vela o periodo.
#   - Sirve para identificar resistencias o niveles clave.
#
# - **L (Low)**
#   - Precio bajo o minimo alcanzado en una vela o periodo.
#   - Sirve para identificar soportes o pisos de precio.
#
# - **HH (Higher Highs)**
#   - Maximos cada vez mas altos.
#   - Indica tendencia alcista fuerte.
#
# - **LL (Lower Lows)**
#   - Minimos cada vez mas bajos.
#   - Indica tendencia bajista fuerte.
#
# - **HL (Higher Low)**
#   - Minimos cada vez mas altos.
#   - Señal de continuidad alcista, compradores entran antes de que caiga mas el precio.
#
# - **LH (Lower High)**
#   - Maximos cada vez mas bajos.
#   - Señal de continuidad bajista, vendedores entran antes de que suba mas el precio.

# %% [markdown]
# # Soportes y Resistencias
#
# ## Que son
#
# - Un **soporte** es un nivel del grafico donde el precio **deja de caer** y **rebota al alza**. Representa una zona donde los compradores entran y evitan que el precio siga bajando.
#
# - Una **resistencia** es un nivel donde el precio **deja de subir** y **gira a la baja**. Representa una zona donde los vendedores intervienen y frenan el avance del precio.
#
# **En resumen:**
# - El **limite inferior** es el soporte.
# - El **limite superior** es la resistencia.
# - Son puntos donde el precio **se detiene temporalmente** y puede **cambiar de direccion**.
#
# ---
#
# ## Por que son importantes
#
# - Ayudan a **anticipar zonas de giro** del mercado.
# - Sirven para **colocar ordenes de entrada, salida y stop loss** de forma mas precisa.
# - Actuan como **niveles psicologicos** que influyen en el comportamiento de los traders.
# - Un soporte roto puede convertirse en **resistencia** y una resistencia rota puede volverse **soporte**.
# - Son una base clave para estrategias de **rebotes**, **rupturas (breakouts)** y **pullbacks**.
#
# ---
#
# ## Tipos de soportes y resistencias
#
# ### 1. Dinamicos
#
# - Se determinan con **indicadores que se mueven junto al precio**, como:
#   - Medias moviles (EMA, SMA)
#   - Bandas de Bollinger
#   - Nubes de Ichimoku
#
# - No marcan un nivel fijo: **se ajustan constantemente** al movimiento del mercado.
# - Evolucionan junto con **tiempo y precio**.
# - Son muy utiles para operar **en tendencias**.
#
# *Ejemplo:* si el precio rebota repetidamente en la media movil de 50 periodos, esa media funciona como **soporte dinamico**.
#
#
# + ![image.png](attachment:a9d59d31-9e0c-44e6-80fd-7e70c313220f.png)
#
# ---
#
# ### 2. Semi-dinamicos
#
# - Son niveles **intermedios entre horizontales y dinamicos**.
# - Se calculan con **formulas o proporciones** que se **actualizan de forma periodica**, no en tiempo real.
# - Ejemplos:
#   - Retrocesos de Fibonacci
#   - Pivot points (diarios, semanales o mensuales)
#   - Rangos calculados con promedios periodicos
#
# - Cambian de forma **escalonada**, por ejemplo al cierre diario o semanal.
# - Se desarrollan en **tiempo y precio**, pero con menos frecuencia que los dinamicos.
#
# *Ejemplo:* un nivel de retroceso Fibonacci 0.618 que se recalcula al final del dia actua como **zona de soporte o resistencia semi-dinamica**.
#
# + ![image.png](attachment:8db6c054-1d4b-4ef4-a8f4-abcbe8eac937.png)
#
# ---
#
# ### 3. Horizontales
#
# - Son **niveles fijos** donde el precio **rebota repetidamente** antes de romper.
# - No evolucionan con el tiempo: se mantienen **estables** hasta que el precio rompe el nivel.
# - Se identifican observando zonas con varios rebotes previos.
# - Se desarrolla principalmente **tiempo**, el **precio cambia** solo al romperse.
# - Suelen coincidir con **niveles psicologicos** (ej. 1000, 20000, 50000).
#
# *Ejemplo:* si el precio toca 20000 varias veces y rebota, esa zona es una **resistencia horizontal**.
#
#
#
# + ![image.png](attachment:b87faeb2-71bf-4409-a1c5-3adea4db56f2.png)
#
# ---
#
# ### 4. Diagonales
#
# - Se trazan uniendo **maximos o minimos crecientes o decrecientes**.
# - Forman lineas **con pendiente alcista o bajista**.
# - Se dibujan **manualmente** segun la tendencia.
# - Evolucionan en el tiempo de forma **diagonal**.
# - Sirven para **identificar tendencias** y **zonas de rebote** dentro de un canal.
#
# *Ejemplo:* en una tendencia alcista, una linea uniendo minimos ascendentes actua como **soporte diagonal**
#
# - ![image.png](attachment:1e6cc678-5748-4a47-abbf-5eec3810b872.png)
#
# ---
#
# ## Cambio de rol: Soporte ↔ Resistencia
#
# - Cuando el **precio rompe un soporte**, ese nivel roto puede **convertirse en resistencia futura**.
# - Cuando el **precio rompe una resistencia**, esta puede **convertirse en soporte**.
# - Este fenomeno se llama **cambio de polaridad**.
# - Es clave para estrategias de **breakout** y **pullback**.
#
# *Ejemplo:* si el precio rompe 1800 hacia abajo y luego vuelve a subir, 1800 puede actuar como resistencia.
#
# ---
#
# ## Consejos practicos
#
# - Cuantos **mas toques** tenga un nivel, **mas fuerte** es.
# - Evita llenar el grafico de niveles: enfocate en los **mas relevantes**.
# - Combina soportes y resistencias con:
#   - Volumen
#   - Patrones de velas japonesas
#   - Lineas de tendencia o canales
# - No son puntos exactos, sino **zonas**.
# - Cuidado con los **falsos rompimientos (fakeouts)**: confirma antes de operar.
#
# ---
#
# ## Estrategias basicas
#
# 1. **Rebote**
#    - Comprar en soporte o vender en resistencia.
#    - Colocar stop loss debajo (o encima) del nivel.
#
# 2. **Ruptura (Breakout)**
#    - Operar cuando el precio rompe un nivel con fuerza.
#    - Confirmar con volumen alto o cierre fuera del rango.
#
# 3. **Pullback**
#    - Esperar que el precio rompa un nivel y vuelva a testearlo.
#    - Entrar en la direccion del movimiento principal.
#
# ---
#
# # Terminos
#
# ## Breakout y Pullback
#
# ### Breakout (Ruptura)
#
# Un **breakout** ocurre cuando el **precio atraviesa con fuerza** un nivel importante de soporte o resistencia.
# Este movimiento suele ir acompañado de **mayor volumen**, lo que indica **fuerza en la nueva direccion**.
#
# - Si el precio **rompe una resistencia**, puede indicar el **inicio de una tendencia alcista**.
# - Si el precio **rompe un soporte**, puede indicar el **inicio de una tendencia bajista**.
#
# *Ejemplo:*
# Si el precio ha rebotado varias veces en 20000 y finalmente **rompe ese nivel hacia arriba** con fuerza, se considera un **breakout alcista**.
#
# Caracteristicas comunes:
# - Velas grandes y solidas.
# - Aumento de volumen.
# - Alta probabilidad de continuacion del movimiento.
# - Muchos traders aprovechan estos movimientos para **entrar en la nueva tendencia**.
#
# ---
#
# ### Pullback (Retroceso controlado)
#
# Un **pullback** ocurre cuando, **despues de un breakout**, el precio **retrocede temporalmente** para **probar nuevamente** el nivel que rompio.
# Si ese nivel ahora **actua como soporte o resistencia inversa**, confirma la **validez de la ruptura**.
#
# - Si rompe una resistencia y luego baja a probarla como soporte → pullback alcista.
# - Si rompe un soporte y luego sube a probarlo como resistencia → pullback bajista.
#
# *Ejemplo:*
# El precio rompe 20000 hacia arriba, sube hasta 20500 y **retrocede nuevamente a 20000**.
# Si rebota en 20000 sin volver a caer, ese pullback confirma la **nueva tendencia alcista**.
#
# Caracteristicas comunes:
# - Retroceso moderado y controlado.
# - Confirma niveles importantes.
# - Ofrece una **segunda oportunidad de entrada** con menor riesgo.
# - Muy utilizado por traders para **entrar despues de la ruptura inicial**.
#
# ---
#
# ## Breakout vs Pullback
#
# | Caracteristica         | Breakout                          | Pullback                                 |
# |-------------------------|-------------------------------------|-------------------------------------------|
# | Momento                | Justo cuando se rompe un nivel     | Despues de la ruptura                    |
# | Direccion              | Movimiento fuerte inicial          | Retroceso controlado                     |
# | Objetivo               | Aprovechar la fuerza del impulso  | Confirmar la validez del nivel roto      |
# | Riesgo                 | Mayor (entrada en movimiento rapido) | Menor (entrada tras confirmacion)      |
# | Estrategia             | Entrar en la ruptura               | Entrar en el rebote tras la ruptura     |
#
#
# ## Tabla resumen
#
# | Tipo           | Naturaleza                | Nivel fijo | Evoluciona | Frecuencia de cambio     | Identificacion                       | Uso principal                           |
# |----------------|----------------------------|------------|------------|--------------------------|---------------------------------------|------------------------------------------|
# | Dinamico       | Indicadores en tiempo real | ❌ No      | ✅ Si      | Constante (tick a tick)  | Medias moviles, Bollinger            | Seguir tendencia                         |
# | Semi-dinamico  | Calculos periodicos        | ❌ No      | ✅ Si      | Escalonada (diaria/semanal) | Fibonacci, pivots                  | Confirmar zonas clave periodicas         |
# | Horizontal     | Zonas fijas                | ✅ Si      | ❌ No      | Ninguna                  | Rebotes historicos                  | Rangos laterales y niveles psicologicos  |
# | Diagonal       | Lineas de tendencia        | ❌ No      | ✅ Si      | Manual y continua         | Maximos/minimos crecientes o decrecientes | Identificar tendencias y rebotes     |

# %% [markdown]
# # Como dibujar soportes y resistencias
#
# ## 1. Soportes y resistencias dinamicos
# - No se dibujan con lineas; el grafico los muestra solo usando medias moviles como la EMA20, EMA50 o EMA200.
# - Estas lineas cambian junto con el precio y ayudan a ver si el precio rebota (soporte) o se frena (resistencia).
# - Cuanto mas veces el precio toque una media y rebote, mas fuerte es ese nivel.
#
# ---
#
# ## 2. Soportes y resistencias horizontales
# - Son los niveles mas usados. Se dibujan con lineas o zonas planas donde el precio se ha detenido o rebotado varias veces.
# - Como hacerlo:
#   1. Mira el grafico y busca los puntos donde el precio se detuvo o cambio de direccion.
#   2. La mejor forma de ubicar la linea es empezar donde el precio esta cotizando actualmente, y luego ajustarla para que coincida con los ultimos rebotes o frenos (OJO es peligroso)
#   3. Otra forma es buscar las barras poderosas, para las alcistas se pone soportes (se pone abajo de la barra) y las bajista como resistencia (se pone arriba de la barra)
#   4. Dibuja una linea horizontal que pase por esos puntos (mechas o cierres de velas).
#   5. Cuantos mas toques tenga, mas importante sera.
# - Ejemplo: si el precio sube, toca varias veces un mismo nivel y baja, ahi tienes una resistencia. Si baja, toca varias veces y sube, ahi tienes un soporte.
#
# ---
#
# ## 3. Soportes y resistencias diagonales
# - Se trazan en forma de linea inclinada.
# - Como hacerlo:
#   1. Si el precio va subiendo, une los minimos mas bajos (se buscan los ultimos 2 o 3 minimos) → soporte diagonal.
#   2. Si el precio va bajando, une los maximos mas altos (se buscan los ultimos 2 o 3 maximos) → resistencia diagonal.
#   3. Cuantos mas puntos toque esa linea sin romperla, mejor funciona.
# - Sirven para ver la direccion de la tendencia y posibles rompimientos.
#
# ---
#
# ## 4. Soportes y resistencias semi-dinamicos
# - No son fijos ni cambian todo el tiempo, sino que se ajustan poco a poco con el movimiento del precio.
# - Ejemplos:
#   - Los ultimos picos o valles (puntos recientes donde el precio reboto fuerte).
#   - Los niveles donde hubo mucho movimiento o pausa antes de un cambio.
# - Como dibujarlos:
#   1. Marca los ultimos rebotes fuertes o zonas de pausa.
#   2. Actualiza esos niveles cuando el grafico cree nuevos puntos importantes.
#
# ---
#
# ## 5. Consejos rapidos
# - Empieza con los niveles horizontales (los mas faciles de ver).
# - Luego agrega lineas diagonales para marcar la tendencia.
# - Usa las medias moviles para confirmar zonas dinamicas.
# - No llenes el grafico de lineas: pocos niveles, pero claros.
# - Cuantas mas veces el precio respete un nivel, mas fuerte sera.
#
# ---
#
# # Reglas (caracteristicas):
#
# + Minimo deben haber 2 toques, no puede ser un nivel de resistencia

# %% [markdown]
# # Libros:
#
# + Análisis técnico de los mercados financieros de John J. Murphy
